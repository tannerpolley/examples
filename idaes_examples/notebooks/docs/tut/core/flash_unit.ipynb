# %%
###############################################################################
# The Institute for the Design of Advanced Energy Systems Integrated Platform
# Framework (IDAES IP) was produced under the DOE Institute for the
# Design of Advanced Energy Systems (IDAES).
#
# Copyright (c) 2018-2023 by the software owners: The Regents of the
# University of California, through Lawrence Berkeley National Laboratory,
# National Technology & Engineering Solutions of Sandia, LLC, Carnegie Mellon
# University, West Virginia University Research Corporation, et al.
# All rights reserved.  Please see the files COPYRIGHT.md and LICENSE.md
# for full copyright and license information.
###############################################################################

# %% [markdown]
# # Flash Unit Model Tutorial
#
# Author: Jaffer Ghouse<br>
# Maintainer: Tanner Polley<br>
# Updated: 2025-06-03
#
# In this module, we will familiarize ourselves with the IDAES framework by creating and working with a flowsheet that contains a single flash tank. The flash tank will be used to perform separation of Benzene and Toluene.
#
# The general workflow of setting up an IDAES flowsheet is the following: <br>
#
# &nbsp;&nbsp;&nbsp;&nbsp; 1 Importing Modules <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 2 Building a Model <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 3 Scaling the Model <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 4 Specifying the Model <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 5 Initializing the Model <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 6 Solving the Model <br>
# &nbsp;&nbsp;&nbsp;&nbsp; 7 Analyzing and Visualizing the Results <br>
#
# We will complete each of these steps as well as demonstrate analyses on this model through some examples and exercises.
#
# ## Key links to documentation
# * Main IDAES online documentation page: https://idaes-pse.readthedocs.io/en/stable/
# * General Workflow: https://idaes-pse.readthedocs.io/en/stable/how_to_guides/workflow/general.html
# * Flash Unit Model Documentation: https://idaes-pse.readthedocs.io/en/stable/reference_guides/model_libraries/generic/unit_models/flash.html

# %% [markdown]
# ## 1 Import Modules
#
# In the next cell, we will perform the necessary imports to get us started. From `pyomo.environ` (a standard import for the Pyomo package), we are importing `ConcreteModel` (to create the Pyomo model that will contain the IDAES flowsheet) and `SolverFactory` (to create the object we will use to solve the equations). We will also import `Constraint` as we will be adding a constraint to the model later in the module. Lastly, we also import `value` from Pyomo. This is a function that can be used to return the current numerical value for variables and parameters in the model. These are all part of Pyomo.
#
# We will also import the main `FlowsheetBlock` from IDAES. The flowsheet block will contain our unit model. `%matplotinline` allows plots to be displayed within the jupyter cell block output rather than in a separate window.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the cell below to perform the imports. Let a workshop organizer know if you see any errors.
# </div>

# %%
from pyomo.environ import ConcreteModel, SolverFactory, Constraint, value
from idaes.core import FlowsheetBlock

# Import idaes logger to set output levels
import idaes.logger as idaeslog

# %matplotlib inline

# %% [markdown]
# ## 2 Create the Model and IDAES Flowsheet
#
# In the next cell, we will create the `ConcreteModel` object often named `m` (which comes from Pyomo) and then connect the `FlowsheetBlock` (which comes from IDAES) to `m`. We ensure `dynamic=False` since this is a steady-state problem. This creates our overall model and adds the flowsheet capabilities that IDAES provides to the Pyomo model.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the cell below to create the objects
# </div>

# %%
m = ConcreteModel()
m.fs = FlowsheetBlock(dynamic=False)

# %% [markdown]
# At this point, we have a single Pyomo model that contains an (almost) empty flowsheet block. Lets use the `m.pprint()` to investigate the current contents of the model.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Use the pprint method on the model, i.e. m.pprint(), to see what is currently contained in the model.
# </div>

# %%
# Todo: call pprint on the model

# %%
# Todo: call pprint on the model
m.pprint()
# Out:
# 1 Block Declarations
#     fs : Size=1, Index=None, Active=True
#         1 Set Declarations
#             _time : Size=1, Index=None, Ordered=Insertion
#                 Key  : Dimen : Domain : Size : Members
#                 None :     1 :    Any :    1 :  {0.0,}
#
#         1 Declarations: _time
#
# 1 Declarations: fs

# %% [markdown]
# ### 2.1 Define Properties
#
# We need to define the property package for our flowsheet. In this example, we will be using the ideal property package that is available as part of the IDAES framework. This property package supports ideal gas - ideal liquid, ideal gas - NRTL, and ideal gas - Wilson models for VLE. More details on this property package can be found at: https://idaes-pse.readthedocs.io/en/stable/reference_guides/model_libraries/generic/property_models/activity_coefficient.html
#
# IDAES also supports creation of your own property packages that will be shown in a later module. More details can be found here https://idaes-examples.readthedocs.io/en/latest/docs/properties/custom/index.html
#
# For this workshop, we will import the BTX_activity_coeff_VLE property parameter block to be used in the flowsheet. This properties block will be passed to our unit model to define the appropriate state variables and equations for performing thermodynamic calculations.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the following two cells to import and create the properties block.
# </div>

# %%
from idaes.models.properties.activity_coeff_models.BTX_activity_coeff_VLE import (
    BTXParameterBlock,
)

# %%
m.fs.properties = BTXParameterBlock(
    valid_phase=("Liq", "Vap"), activity_coeff_model="Ideal", state_vars="FTPz"
)

# %% [markdown]
# ### 2.2 Adding Flash Unit
#
# Now that we have the flowsheet and the properties defined, we can create the flash unit and add it to the flowsheet.
#
# **The Unit Model Library within IDAES includes a large set of common unit operations (see the online documentation for details: https://idaes-pse.readthedocs.io/en/stable/reference_guides/model_libraries/generic/unit_models/index.html**
#
# IDAES also fully supports the development of customized unit models (which we will see in a later module). More details can be found here https://idaes-examples.readthedocs.io/en/latest/docs/unit_models/custom_unit_models/index.html.
#
# Some of the IDAES pre-written unit models:
# * Mixer / Splitter
# * Heater / Cooler
# * Heat Exchangers (simple and 1D discretized)
# * Flash
# * Reactors (kinetic, equilibrium, gibbs, stoichiometric conversion)
# * Pressure changing equipment (compressors, expanders, pumps)
# * Feed and Product (source / sink) components
#
# In this module, we will import the `Flash` unit model from `idaes.models.unit_models` and create an instance of the flash unit, attaching it to the flowsheet. Each IDAES unit model has several configurable options to customize the model behavior, but also includes defaults for these options. In this example, we will specify that the property package to be used with the Flash unit model is the one we created earlier by setting `property_package=m.fs.properties` within the `Flash` method.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the following two cells to import the Flash and create an instance of the unit model, attaching it to the flowsheet object.
# </div>

# %%
from idaes.models.unit_models import Flash

# %%
m.fs.flash = Flash(property_package=m.fs.properties)

# %% [markdown]
# At this point, we have created a flowsheet and a properties block. We have also created a flash unit and added it to the flowsheet. Under the hood, IDAES has created the required state variables and model equations. Everything is open. You can see these variables and equations by calling the Pyomo method `pprint` on the model, flowsheet, or flash tank objects. Note that this output is very exhaustive, and is not intended to provide any summary information about the model, but rather a complete picture of all of the variables and equations in the model.

# %%
m.pprint()
# Out:
# 1 Block Declarations
#     fs : Size=1, Index=None, Active=True
#         1 Set Declarations
#             _time : Size=1, Index=None, Ordered=Insertion
#                 Key  : Dimen : Domain : Size : Members
#                 None :     1 :    Any :    1 :  {0.0,}
#
#         2 Block Declarations
#             flash : Size=1, Index=None, Active=True
#                 6 Var Declarations
#                     _flow_mol_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_in[...].component('flow_mol')
#                         Key : Lower : Value : Upper : Fixed : Stale : Domain
#                         0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#                     _mole_frac_comp_inlet_ref : Size=2, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.flash.control_volume.properties_in[...].component('mole_frac_comp')[...]
#                         Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                         (0.0, 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                         (0.0, 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                     _pressure_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_in[...].component('pressure')
#                         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                         0.0 :     0 : 101325 :  None : False : False : NonNegativeReals
#                     _temperature_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_in[...].component('temperature')
#                         Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                         0.0 :     0 : 298.15 :  None : False : False : NonNegativeReals
#                     deltaP : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.deltaP[:]
#                         Key : Lower : Value : Upper : Fixed : Stale : Domain
#                         0.0 :  None :   0.0 :  None : False : False :  Reals
#                     heat_duty : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.heat[:]
#                         Key : Lower : Value : Upper : Fixed : Stale : Domain
#                         0.0 :  None :   0.0 :  None : False : False :  Reals
#
#                 2 Block Declarations
#                     control_volume : Size=1, Index=None, Active=True
#                         2 Var Declarations
#                             deltaP : Pressure difference across unit
#                                 Size=1, Index=fs._time, Units=kg/m/s**2
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 0.0 :  None :   0.0 :  None : False : False :  Reals
#                             heat : Heat transferred into control volume
#                                 Size=1, Index=fs._time, Units=kg*m**2/s**3
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 0.0 :  None :   0.0 :  None : False : False :  Reals
#
#                         3 Constraint Declarations
#                             enthalpy_balances : Energy balances
#                                 Size=1, Index=fs._time, Active=True
#                                 Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            : Upper : Active
#                                 0.0 :   0.0 : (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Liq]) + (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Vap]) - ((fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_out[0.0].enth_mol_phase[Liq]) + (fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_out[0.0].enth_mol_phase[Vap])) + fs.flash.control_volume.heat[0.0] :   0.0 :   True
#                             material_balances : Material balances
#                                 Size=2, Index=fs._time*fs.properties.component_list, Active=True
#                                 Key              : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                : Upper : Active
#                                 (0.0, 'benzene') :   0.0 : (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]) + (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]) - ((fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,benzene]) + (fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,benzene])) :   0.0 :   True
#                                 (0.0, 'toluene') :   0.0 : (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]) + (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) - ((fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,toluene]) + (fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,toluene])) :   0.0 :   True
#                             pressure_balance : Momentum balance
#                                 Size=1, Index=fs._time, Active=True
#                                 Key : Lower : Body                                                                                                                                             : Upper : Active
#                                 0.0 :   0.0 : fs.flash.control_volume.properties_in[0.0].pressure - fs.flash.control_volume.properties_out[0.0].pressure + fs.flash.control_volume.deltaP[0.0] :   0.0 :   True
#
#                         2 Block Declarations
#                             properties_in : Material properties at inlet
#                                 Size=1, Index=fs._time, Active=True
#                                 fs.flash.control_volume.properties_in[0.0] : Active=True
#                                     2 Param Declarations
#                                         eps_1 : Smoothing parameter for equilibrium temperature
#                                             Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True, Units=K
#                                             Key : Value
#                                         eps_2 : Smoothing parameter for equilibrium temperature
#                                             Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True, Units=K
#                                             Key : Value
#
#                                     13 Var Declarations
#                                         _t1 : Intermediate temperature for calculating the equilibrium temperature
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#                                         _temperature_equilibrium : Temperature for calculating phase equilibrium
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#                                         enth_mol_phase : Phase molar specific enthalpies [J/mol]
#                                             Size=2, Index=fs.properties.phase_list, Units=J/mol
#                                             Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                             Liq :  None :  None :  None : False :  True :  Reals
#                                             Vap :  None :  None :  None : False :  True :  Reals
#                                         enth_mol_phase_comp : Phase-component molar specific enthalpies [J/mol]
#                                             Size=4, Index=fs.properties._phase_component_set, Units=J/mol
#                                             Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                             ('Liq', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                             ('Liq', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                             ('Vap', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                             ('Vap', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                         flow_mol : Total molar flowrate [mol/s]
#                                             Size=1, Index=None, Units=mol/s
#                                             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                                             None :     0 :   1.0 :  None : False : False : NonNegativeReals
#                                         flow_mol_phase : Size=2, Index=fs.properties.phase_list, Units=mol/s
#                                             Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                             Liq :  None :   0.5 :  None : False : False :  Reals
#                                             Vap :  None :   0.5 :  None : False : False :  Reals
#                                         mole_frac_comp : Mixture mole fraction
#                                             Size=2, Index=fs.properties.component_list
#                                             Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                                             benzene :     0 :   0.5 :     1 : False : False :  Reals
#                                             toluene :     0 :   0.5 :     1 : False : False :  Reals
#                                         mole_frac_phase_comp : Size=4, Index=fs.properties._phase_component_set
#                                             Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                             ('Liq', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                             ('Liq', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                                             ('Vap', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                             ('Vap', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                                         pressure : State pressure [Pa]
#                                             Size=1, Index=None, Units=Pa
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :     0 : 101325 :  None : False : False : NonNegativeReals
#                                         pressure_sat_comp : vapor pressure
#                                             Size=2, Index=fs.properties.component_list, Units=Pa
#                                             Key     : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             benzene :  None : 101325 :  None : False : False :  Reals
#                                             toluene :  None : 101325 :  None : False : False :  Reals
#                                         temperature : State temperature [K]
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :     0 : 298.15 :  None : False : False : NonNegativeReals
#                                         temperature_bubble : Bubble point temperature (K)
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#                                         temperature_dew : Dew point temperature (K)
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#
#                                     6 Expression Declarations
#                                         _p_sat_bubbleT : Size=2, Index=fs.properties.component_list
#                                             Key     : Expression
#                                             benzene : fs.properties.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble) + 1.33213*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.62863*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**3 - 3.33399*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)))
#                                             toluene : fs.properties.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble) + 1.38091*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.83433*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**3 - 2.79168*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)))
#                                         _p_sat_dewT : Size=2, Index=fs.properties.component_list
#                                             Key     : Expression
#                                             benzene : fs.properties.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew) + 1.33213*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.62863*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**3 - 3.33399*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)))
#                                             toluene : fs.properties.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew) + 1.38091*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.83433*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**3 - 2.79168*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)))
#                                         _reduced_temp : Size=2, Index=fs.properties.component_list
#                                             Key     : Expression
#                                             benzene : (fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene]
#                                             toluene : (fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene]
#                                         enthalpy_flow_terms : Size=2, Index=fs.properties.phase_list
#                                             Key : Expression
#                                             Liq : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Liq]
#                                             Vap : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Vap]
#                                         fug_phase_comp : Size=4, Index=fs.properties.phase_list*fs.properties.component_list
#                                             Key                : Expression
#                                             ('Liq', 'benzene') : fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[benzene]
#                                             ('Liq', 'toluene') : fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[toluene]
#                                             ('Vap', 'benzene') :                   fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]*fs.flash.control_volume.properties_in[0.0].pressure
#                                             ('Vap', 'toluene') :                   fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]*fs.flash.control_volume.properties_in[0.0].pressure
#                                         material_flow_terms : Size=4, Index=fs.properties.phase_list*fs.properties.component_list
#                                             Key                : Expression
#                                             ('Liq', 'benzene') : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]
#                                             ('Liq', 'toluene') : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]
#                                             ('Vap', 'benzene') : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]
#                                             ('Vap', 'toluene') : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]
#
#                                     11 Constraint Declarations
#                                         _t1_constraint : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                    : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0]._t1 - 0.5*(fs.flash.control_volume.properties_in[0.0].temperature + fs.flash.control_volume.properties_in[0.0].temperature_bubble + sqrt((fs.flash.control_volume.properties_in[0.0].temperature - fs.flash.control_volume.properties_in[0.0].temperature_bubble)**2 + fs.flash.control_volume.properties_in[0.0].eps_1**2)) :   0.0 :   True
#                                         _teq_constraint : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                   : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium - 0.5*(fs.flash.control_volume.properties_in[0.0]._t1 + fs.flash.control_volume.properties_in[0.0].temperature_dew - sqrt((fs.flash.control_volume.properties_in[0.0]._t1 - fs.flash.control_volume.properties_in[0.0].temperature_dew)**2 + fs.flash.control_volume.properties_in[0.0].eps_2**2)) :   0.0 :   True
#                                         eq_P_vap : Size=2, Index=fs.properties.component_list, Active=True
#                                             Key     : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        : Upper : Active
#                                             benzene :   0.0 : (1 - ((fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene]))*log(1/fs.properties.pressure_critical[benzene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[benzene]) - (-6.98273*((fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene]) + 1.33213*((fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene])**1.5 - 2.62863*((fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene])**3 - 3.33399*((fs.properties.temperature_critical[benzene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[benzene])**6) :   0.0 :   True
#                                             toluene :   0.0 : (1 - ((fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene]))*log(1/fs.properties.pressure_critical[toluene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[toluene]) - (-7.28607*((fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene]) + 1.38091*((fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene])**1.5 - 2.83433*((fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene])**3 - 2.79168*((fs.properties.temperature_critical[toluene] - fs.flash.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.properties.temperature_critical[toluene])**6) :   0.0 :   True
#                                         eq_comp : Size=2, Index=fs.properties.component_list, Active=True
#                                             Key     : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                 : Upper : Active
#                                             benzene :   0.0 : fs.flash.control_volume.properties_in[0.0].flow_mol*fs.flash.control_volume.properties_in[0.0].mole_frac_comp[benzene] - (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]) :   0.0 :   True
#                                             toluene :   0.0 : fs.flash.control_volume.properties_in[0.0].flow_mol*fs.flash.control_volume.properties_in[0.0].mole_frac_comp[toluene] - (fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene] + fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                                         eq_enth_mol_phase : Size=2, Index=fs.properties.phase_list, Active=True
#                                             Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                   : Upper : Active
#                                             Liq :   0.0 : fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Liq] - (fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,benzene]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,toluene]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]) :   0.0 :   True
#                                             Vap :   0.0 : fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Vap] - (fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,benzene]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene] + fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,toluene]*fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                                         eq_enth_mol_phase_comp : Size=4, Index=fs.properties._phase_component_set, Active=True
#                                             Key                : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  : Upper : Active
#                                             ('Liq', 'benzene') :   0.0 : fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,benzene] - (fs.properties.dh_form[Liq,benzene] + 0.001*(kmol/mol)*(fs.properties.cp_mol_liq_comp_coeff_E[benzene]/5*(fs.flash.control_volume.properties_in[0.0].temperature**5 - fs.properties.temperature_reference**5) + fs.properties.cp_mol_liq_comp_coeff_D[benzene]/4*(fs.flash.control_volume.properties_in[0.0].temperature**4 - fs.properties.temperature_reference**4) + fs.properties.cp_mol_liq_comp_coeff_C[benzene]/3*(fs.flash.control_volume.properties_in[0.0].temperature**3 - fs.properties.temperature_reference**3) + fs.properties.cp_mol_liq_comp_coeff_B[benzene]/2*(fs.flash.control_volume.properties_in[0.0].temperature**2 - fs.properties.temperature_reference**2) + fs.properties.cp_mol_liq_comp_coeff_A[benzene]*(fs.flash.control_volume.properties_in[0.0].temperature - fs.properties.temperature_reference))) :   0.0 :   True
#                                             ('Liq', 'toluene') :   0.0 : fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,toluene] - (fs.properties.dh_form[Liq,toluene] + 0.001*(kmol/mol)*(fs.properties.cp_mol_liq_comp_coeff_E[toluene]/5*(fs.flash.control_volume.properties_in[0.0].temperature**5 - fs.properties.temperature_reference**5) + fs.properties.cp_mol_liq_comp_coeff_D[toluene]/4*(fs.flash.control_volume.properties_in[0.0].temperature**4 - fs.properties.temperature_reference**4) + fs.properties.cp_mol_liq_comp_coeff_C[toluene]/3*(fs.flash.control_volume.properties_in[0.0].temperature**3 - fs.properties.temperature_reference**3) + fs.properties.cp_mol_liq_comp_coeff_B[toluene]/2*(fs.flash.control_volume.properties_in[0.0].temperature**2 - fs.properties.temperature_reference**2) + fs.properties.cp_mol_liq_comp_coeff_A[toluene]*(fs.flash.control_volume.properties_in[0.0].temperature - fs.properties.temperature_reference))) :   0.0 :   True
#                                             ('Vap', 'benzene') :   0.0 :                    fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,benzene] - (fs.properties.cp_mol_vap_comp_coeff_E[benzene]/5*(fs.flash.control_volume.properties_in[0.0].temperature**5 - fs.properties.temperature_reference**5) + fs.properties.cp_mol_vap_comp_coeff_D[benzene]/4*(fs.flash.control_volume.properties_in[0.0].temperature**4 - fs.properties.temperature_reference**4) + fs.properties.cp_mol_vap_comp_coeff_C[benzene]/3*(fs.flash.control_volume.properties_in[0.0].temperature**3 - fs.properties.temperature_reference**3) + fs.properties.cp_mol_vap_comp_coeff_B[benzene]/2*(fs.flash.control_volume.properties_in[0.0].temperature**2 - fs.properties.temperature_reference**2) + fs.properties.cp_mol_vap_comp_coeff_A[benzene]*(fs.flash.control_volume.properties_in[0.0].temperature - fs.properties.temperature_reference) + fs.properties.dh_form[Vap,benzene]) :   0.0 :   True
#                                             ('Vap', 'toluene') :   0.0 :                    fs.flash.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,toluene] - (fs.properties.cp_mol_vap_comp_coeff_E[toluene]/5*(fs.flash.control_volume.properties_in[0.0].temperature**5 - fs.properties.temperature_reference**5) + fs.properties.cp_mol_vap_comp_coeff_D[toluene]/4*(fs.flash.control_volume.properties_in[0.0].temperature**4 - fs.properties.temperature_reference**4) + fs.properties.cp_mol_vap_comp_coeff_C[toluene]/3*(fs.flash.control_volume.properties_in[0.0].temperature**3 - fs.properties.temperature_reference**3) + fs.properties.cp_mol_vap_comp_coeff_B[toluene]/2*(fs.flash.control_volume.properties_in[0.0].temperature**2 - fs.properties.temperature_reference**2) + fs.properties.cp_mol_vap_comp_coeff_A[toluene]*(fs.flash.control_volume.properties_in[0.0].temperature - fs.properties.temperature_reference) + fs.properties.dh_form[Vap,toluene]) :   0.0 :   True
#                                         eq_phase_equilibrium : Size=2, Index=fs.properties.component_list, Active=True
#                                             Key     : Lower : Body                                                                                                                                                                                                                                                                                      : Upper : Active
#                                             benzene :   0.0 : (fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]*fs.flash.control_volume.properties_in[0.0].pressure) - (fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[benzene]) :   0.0 :   True
#                                             toluene :   0.0 : (fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]*fs.flash.control_volume.properties_in[0.0].pressure) - (fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]*fs.flash.control_volume.properties_in[0.0].pressure_sat_comp[toluene]) :   0.0 :   True
#                                         eq_sum_mol_frac : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                        : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene] - (fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene] + fs.flash.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                                         eq_temperature_bubble : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0].mole_frac_comp[benzene]*(fs.properties.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble) + 1.33213*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.62863*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**3 - 3.33399*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)))) + fs.flash.control_volume.properties_in[0.0].mole_frac_comp[toluene]*(fs.properties.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble) + 1.38091*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.83433*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**3 - 2.79168*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_bubble)))) - fs.flash.control_volume.properties_in[0.0].pressure :   0.0 :   True
#                                         eq_temperature_dew : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0].pressure*(fs.flash.control_volume.properties_in[0.0].mole_frac_comp[benzene]/(fs.properties.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew) + 1.33213*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.62863*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**3 - 3.33399*(1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.properties.temperature_critical[benzene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)))) + fs.flash.control_volume.properties_in[0.0].mole_frac_comp[toluene]/(fs.properties.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew) + 1.38091*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.83433*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**3 - 2.79168*(1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.properties.temperature_critical[toluene]*fs.flash.control_volume.properties_in[0.0].temperature_dew))))) - 1 :   0.0 :   True
#                                         eq_total : Size=1, Index=None, Active=True
#                                             Key  : Lower : Body                                                                                                                                                                                  : Upper : Active
#                                             None :   0.0 : fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Liq] + fs.flash.control_volume.properties_in[0.0].flow_mol_phase[Vap] - fs.flash.control_volume.properties_in[0.0].flow_mol :   0.0 :   True
#
#                                     32 Declarations: flow_mol mole_frac_comp pressure temperature flow_mol_phase mole_frac_phase_comp eq_total eq_comp eq_sum_mol_frac _temperature_equilibrium _t1 eps_1 eps_2 _t1_constraint temperature_bubble _p_sat_bubbleT eq_temperature_bubble _teq_constraint temperature_dew _p_sat_dewT eq_temperature_dew eq_phase_equilibrium fug_phase_comp pressure_sat_comp _reduced_temp eq_P_vap material_flow_terms enthalpy_flow_terms enth_mol_phase eq_enth_mol_phase enth_mol_phase_comp eq_enth_mol_phase_comp
#                             properties_out : Material properties at outlet
#                                 Size=1, Index=fs._time, Active=True
#                                 fs.flash.control_volume.properties_out[0.0] : Active=True
#                                     2 Param Declarations
#                                         eps_1 : Smoothing parameter for equilibrium temperature
#                                             Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True, Units=K
#                                             Key : Value
#                                         eps_2 : Smoothing parameter for equilibrium temperature
#                                             Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True, Units=K
#                                             Key : Value
#
#                                     13 Var Declarations
#                                         _t1 : Intermediate temperature for calculating the equilibrium temperature
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#                                         _temperature_equilibrium : Temperature for calculating phase equilibrium
#                                             Size=1, Index=None, Units=K
#                                             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                             None :  None : 298.15 :  None : False : False :  Reals
#                                         enth_mol_phase : Phase molar specific enthalpies [J/mol]
#                                             Size=2, Index=fs.properties.phase_list, Units=J/mol
#                                             Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                             Liq :  None :  None :  None : False :  True :  Reals
#                                             Vap :  None :  None :  None : False :  True :  Reals
#                                         enth_mol_phase_comp : Phase-component molar specific enthalpies [J/mol]
#                                             Size=4, Index=fs.properties._phase_component_set, Units=J/mol
#                                             Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                             ('Liq', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                             ('Liq', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                             ('Vap', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                             ('Vap', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                         flow_mol : Total molar flowrate [mol/s]
#                                             Size=1, Index=None, Units=mol/s
#                                             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                                             None :     0 :   1.0 :  None : False : False : NonNegativeReals
#                                         flow_mol_phase : Size=2, Index=fs.properties.phase_list, Units=mol/s
#                                             Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                             Liq :  None :   0.5 :  None : False : False :  Reals
#                                             Vap :  None :   0.5 :  None : False : False :  Reals
#                                         mole_frac_comp : Mixture mole fraction
#                                             Size=2, Index=fs.properties.component_list
#                                             Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                                             benzene :     0 :   0.5 :     1 : False : False :  Reals
#                                             toluene :     0 :   0.5 :     1 : False : False :  Reals
#                                         mole_frac_phase_comp : Size=4, Index=fs.properties._phase_component_set
#                                             Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                             ('Liq', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
# ...
#                                 Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 0.0 :     0 : 101325 :  None : False : False : NonNegativeReals
#                             _Vap_temperature_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_out[:].component('temperature')
#                                 Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 0.0 :     0 : 298.15 :  None : False : False : NonNegativeReals
#                             _flow_mol_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_out[...].component('flow_mol')
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#                             _mole_frac_comp_inlet_ref : Size=2, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.flash.control_volume.properties_out[...].component('mole_frac_comp')[...]
#                                 Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                                 (0.0, 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 (0.0, 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                             _pressure_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_out[...].component('pressure')
#                                 Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 0.0 :     0 : 101325 :  None : False : False : NonNegativeReals
#                             _temperature_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.flash.control_volume.properties_out[...].component('temperature')
#                                 Key : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 0.0 :     0 : 298.15 :  None : False : False : NonNegativeReals
#
#                         4 Expression Declarations
#                             _Liq_flow_mol_ref : Size=1, Index=fs._time
#                                 Key : Expression
#                                 0.0 : fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Liq]
#                             _Liq_mole_frac_comp_ref : Size=2, Index=fs._time*fs.properties.component_list
#                                 Key              : Expression
#                                 (0.0, 'benzene') : fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,benzene]
#                                 (0.0, 'toluene') : fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,toluene]
#                             _Vap_flow_mol_ref : Size=1, Index=fs._time
#                                 Key : Expression
#                                 0.0 : fs.flash.control_volume.properties_out[0.0].flow_mol_phase[Vap]
#                             _Vap_mole_frac_comp_ref : Size=2, Index=fs._time*fs.properties.component_list
#                                 Key              : Expression
#                                 (0.0, 'benzene') : fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,benzene]
#                                 (0.0, 'toluene') : fs.flash.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,toluene]
#
#                         3 Port Declarations
#                             Liq : Outlet Port
#                                 Size=1, Index=None
#                                 Key  : Name           : Size : Variable
#                                 None :       flow_mol :    1 :       fs.flash.split._Liq_flow_mol_ref
#                                      : mole_frac_comp :    2 : fs.flash.split._Liq_mole_frac_comp_ref
#                                      :       pressure :    1 :       fs.flash.split._Liq_pressure_ref
#                                      :    temperature :    1 :    fs.flash.split._Liq_temperature_ref
#                             Vap : Outlet Port
#                                 Size=1, Index=None
#                                 Key  : Name           : Size : Variable
#                                 None :       flow_mol :    1 :       fs.flash.split._Vap_flow_mol_ref
#                                      : mole_frac_comp :    2 : fs.flash.split._Vap_mole_frac_comp_ref
#                                      :       pressure :    1 :       fs.flash.split._Vap_pressure_ref
#                                      :    temperature :    1 :    fs.flash.split._Vap_temperature_ref
#                             inlet : Inlet Port
#                                 Size=1, Index=None
#                                 Key  : Name           : Size : Variable
#                                 None :       flow_mol :    1 :       fs.flash.split._flow_mol_inlet_ref
#                                      : mole_frac_comp :    2 : fs.flash.split._mole_frac_comp_inlet_ref
#                                      :       pressure :    1 :       fs.flash.split._pressure_inlet_ref
#                                      :    temperature :    1 :    fs.flash.split._temperature_inlet_ref
#
#                         17 Declarations: inlet _flow_mol_inlet_ref _mole_frac_comp_inlet_ref _temperature_inlet_ref _pressure_inlet_ref eps_flow eps_frac Vap _Vap_flow_mol_ref _Vap_mole_frac_comp_ref _Vap_temperature_ref _Vap_pressure_ref Liq _Liq_flow_mol_ref _Liq_mole_frac_comp_ref _Liq_temperature_ref _Liq_pressure_ref
#
#                 3 Port Declarations
#                     inlet : Inlet Port
#                         Size=1, Index=None
#                         Key  : Name           : Size : Variable
#                         None :       flow_mol :    1 :       fs.flash._flow_mol_inlet_ref
#                              : mole_frac_comp :    2 : fs.flash._mole_frac_comp_inlet_ref
#                              :       pressure :    1 :       fs.flash._pressure_inlet_ref
#                              :    temperature :    1 :    fs.flash._temperature_inlet_ref
#                     liq_outlet : Size=1, Index=None
#                         Key  : Name           : Size : Variable
#                         None :       flow_mol :    1 :       fs.flash.split._Liq_flow_mol_ref
#                              : mole_frac_comp :    2 : fs.flash.split._Liq_mole_frac_comp_ref
#                              :       pressure :    1 :       fs.flash.split._Liq_pressure_ref
#                              :    temperature :    1 :    fs.flash.split._Liq_temperature_ref
#                     vap_outlet : Size=1, Index=None
#                         Key  : Name           : Size : Variable
#                         None :       flow_mol :    1 :       fs.flash.split._Vap_flow_mol_ref
#                              : mole_frac_comp :    2 : fs.flash.split._Vap_mole_frac_comp_ref
#                              :       pressure :    1 :       fs.flash.split._Vap_pressure_ref
#                              :    temperature :    1 :    fs.flash.split._Vap_temperature_ref
#
#                 11 Declarations: control_volume inlet _flow_mol_inlet_ref _mole_frac_comp_inlet_ref _temperature_inlet_ref _pressure_inlet_ref split vap_outlet liq_outlet heat_duty deltaP
#             properties : Size=1, Index=None, Active=True
#                 6 Set Declarations
#                     _phase_component_set : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     2 :    Any :    4 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Vap', 'benzene'), ('Vap', 'toluene')}
#                     component_list : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     1 :    Any :    2 : {'benzene', 'toluene'}
#                     component_list_master : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     1 :    Any :    3 : {'benzene', 'toluene', 'o-xylene'}
#                     phase_equilibrium_idx : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     1 :    Any :    2 : {1, 2}
#                     phase_equilibrium_idx_master : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     1 :    Any :    3 : {1, 2, 3}
#                     phase_list : Size=1, Index=None, Ordered=Insertion
#                         Key  : Dimen : Domain : Size : Members
#                         None :     1 :    Any :    2 : {'Liq', 'Vap'}
#
#                 18 Param Declarations
#                     cp_mol_liq_comp_coeff_A : Liquid phase Cp parameter A
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K/kmol
#                         Key     : Value
#                         benzene : 129000.0
#                         toluene : 140000.0
#                     cp_mol_liq_comp_coeff_B : Liquid phase Cp parameter B
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**2/kmol
#                         Key     : Value
#                         benzene : -170.0
#                         toluene : -152.0
#                     cp_mol_liq_comp_coeff_C : Liquid phase Cp parameter C
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**3/kmol
#                         Key     : Value
#                         benzene : 0.648
#                         toluene : 0.695
#                     cp_mol_liq_comp_coeff_D : Liquid phase Cp parameter D
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**4/kmol
#                         Key     : Value
#                         benzene :     0
#                         toluene :     0
#                     cp_mol_liq_comp_coeff_E : Liquid phase Cp parameter E
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**5/kmol
#                         Key     : Value
#                         benzene :     0
#                         toluene :     0
#                     cp_mol_vap_comp_coeff_A : Vapor phase Cp parameter A
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K/mol
#                         Key     : Value
#                         benzene : -33.92
#                         toluene : -24.35
#                     cp_mol_vap_comp_coeff_B : Vapor phase Cp parameter B
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**2/mol
#                         Key     : Value
#                         benzene : 0.4739
#                         toluene : 0.5125
#                     cp_mol_vap_comp_coeff_C : Vapor phase Cp parameter C
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**3/mol
#                         Key     : Value
#                         benzene : -0.0003017
#                         toluene : -0.0002765
#                     cp_mol_vap_comp_coeff_D : Vapor phase Cp parameter D
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**4/mol
#                         Key     : Value
#                         benzene :  7.13e-08
#                         toluene : 4.911e-08
#                     cp_mol_vap_comp_coeff_E : Vapor phase Cp parameter E
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K**5/mol
#                         Key     : Value
#                         benzene :     0
#                         toluene :     0
#                     dh_form : Standard heats of formation [J/mol]
#                         Size=4, Index=fs.properties.phase_list*fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/mol
#                         Key                : Value
#                         ('Liq', 'benzene') : 49000.0
#                         ('Liq', 'toluene') : 12000.0
#                         ('Vap', 'benzene') : 82900.0
#                         ('Vap', 'toluene') : 50100.0
#                     ds_form : Standard entropy of formation [J/mol.K]
#                         Size=4, Index=fs.properties.phase_list*fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=J/K/mol
#                         Key                : Value
#                         ('Liq', 'benzene') :  -173
#                         ('Liq', 'toluene') :  -220
#                         ('Vap', 'benzene') :  -269
#                         ('Vap', 'toluene') :  -321
#                     mw_comp : molecular weight kg/mol
#                         Size=2, Index=fs.properties.component_list, Domain=Any, Default=None, Mutable=True, Units=kg/mol
#                         Key     : Value
#                         benzene : 0.0781136
#                         toluene : 0.0921405
#                     pressure_critical : Critical pressure [Pa]
#                         Size=2, Index=fs.properties.component_list, Domain=NonNegativeReals, Default=None, Mutable=True, Units=Pa
#                         Key     : Value
#                         benzene : 4890000.0
#                         toluene : 4100000.0
#                     pressure_reference : Reference pressure [Pa]
#                         Size=1, Index=None, Domain=Any, Default=101325, Mutable=True, Units=Pa
#                         Key : Value
#                     pressure_sat_coeff : parameters to compute P_sat
#                         Size=8, Index=fs.properties.component_list*{A, B, C, D}, Domain=Any, Default=None, Mutable=False
#                         Key              : Value
#                         ('benzene', 'A') : -6.98273
#                         ('benzene', 'B') :  1.33213
#                         ('benzene', 'C') : -2.62863
#                         ('benzene', 'D') : -3.33399
#                         ('toluene', 'A') : -7.28607
#                         ('toluene', 'B') :  1.38091
#                         ('toluene', 'C') : -2.83433
#                         ('toluene', 'D') : -2.79168
#                     temperature_critical : Critical temperature [K]
#                         Size=2, Index=fs.properties.component_list, Domain=NonNegativeReals, Default=None, Mutable=True, Units=K
#                         Key     : Value
#                         benzene : 562.2
#                         toluene : 591.8
#                     temperature_reference : Reference temperature [K]
#                         Size=1, Index=None, Domain=Any, Default=298.15, Mutable=True, Units=K
#                         Key : Value
#
#                 4 Block Declarations
#                     Liq : Size=1, Index=None, Active=True
#                         0 Declarations:
#                     Vap : Size=1, Index=None, Active=True
#                         0 Declarations:
#                     benzene : Size=1, Index=None, Active=True
#                         0 Declarations:
#                     toluene : Size=1, Index=None, Active=True
#                         0 Declarations:
#
#                 28 Declarations: component_list_master benzene component_list toluene Liq phase_list Vap phase_equilibrium_idx_master phase_equilibrium_idx pressure_reference temperature_reference pressure_critical temperature_critical mw_comp cp_mol_liq_comp_coeff_A cp_mol_liq_comp_coeff_B cp_mol_liq_comp_coeff_C cp_mol_liq_comp_coeff_D cp_mol_liq_comp_coeff_E cp_mol_vap_comp_coeff_A cp_mol_vap_comp_coeff_B cp_mol_vap_comp_coeff_C cp_mol_vap_comp_coeff_D cp_mol_vap_comp_coeff_E pressure_sat_coeff dh_form ds_form _phase_component_set
#
#         3 Declarations: _time properties flash
#
# 1 Declarations: fs

# %% [markdown]
# ## 3 Scaling the Model
#
# Now that the model is built, with properties set and the unit model created and added to the flowsheet, the next step is to scale the model. Ensuring that a model is well scaled is important for increasing the efficiency and reliability of solvers, and users should consider model scaling as an integral part of the modeling process. IDAES provides a number of tool for assisting users with scaling their models, and details on these can be found at https://idaes-pse.readthedocs.io/en/stable/reference_guides/scaling/scaling.html#scaling-toolbox
#
# There are currently two primary methods in scaling the model: manual scaling of each relevant component, or utilizing the AutoScaler Class. The more careful and risk-free method of manually scaling each component is the recommended method for maximum control and assurance that the model will be well-scaled. This comes with the drawback of being more meticulous while the AutoScaler is much simpler to use since it scaled the whole model all at once, it is less precise by lacking direct control over the scaling factor for each component and relying on scaling factors to be estimated. Both methods will be shown below

# %% [markdown]
# ### 3.1 Manual Scaling
# The `set_scaling_factor` function is imported from `idaes.core.scaling.util` and is called with and used on each relevant component that needs to be well scaled. The component is the first argument and its scaling factor is the second argument.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the following two cells to import the `set_scaling_factor` and set the scaling factor for both temperature and pressure
# </div>
#
# Both `temperature` and `pressure` can be found at `m.fs.flash.inlet`.

# %%
from idaes.core.scaling.util import set_scaling_factor

# %%
set_scaling_factor(m.fs.flash.inlet.temperature[0], 300)
set_scaling_factor(m.fs.flash.inlet.pressure[0], 1e6)

# %% [markdown]
# ### 3.2 Scaling with AutoScaler
# The `AutoScaler` class is imported from `idaes.core.scaling.autoscaling` and an instance of the class is created. This instance contains the method `scale_model` which is used to scale the whole model at once. This can be a useful option but is generally more risky than manually scaling the model components since it has less direct control and specification.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the following two cells to import the `AutoScaler` class and create an autoscaler instance that scaled the whole model at once
# </div>

# %%
from idaes.core.scaling.autoscaling import AutoScaler

# %%
autoscaler = AutoScaler()
autoscaler.scale_model(m)

# %% [markdown]
# ## 4 Set Operating Conditions
#
# Now that we have created our unit model and scaled it, we can specify the necessary operating conditions. The inlet specifications for this flash tank are:
#
# Inlet Specifications:
# * Mole fraction (Benzene) = 0.5
# * Mole fraction (Toluene) = 0.5
# * Pressure = 101325 Pa
# * Temperature = 368 K

# %% [markdown]
# ### 4.1 Degrees of Freedom
#
# It is often very useful to first determine the degrees of freedom before we specify any conditions.
#
# The `idaes.core.util.model_statistics` package has a function `degrees_of_freedom`. To see how to use this function, we can make use of the Python function `help(func)`. This function prints the appropriate documentation string for the function.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Import the degrees_of_freedom function and print the help for the function by calling the Python help function.
# </div>

# %%
# Todo: import the degrees_of_freedom function from the idaes.core.util.model_statistics package


# Todo: Call the python help on the degrees_of_freedom function

# %%
# Todo: import the degrees_of_freedom function from the idaes.core.util.model_statistics package
from idaes.core.util.model_statistics import degrees_of_freedom

# Todo: Call the python help on the degrees_of_freedom function
help(degrees_of_freedom)
# Out:
# Help on function degrees_of_freedom in module idaes.core.util.model_statistics:
#
# degrees_of_freedom(block)
#     Method to return the degrees of freedom of a model.
#
#     Args:
#         block : model to be studied
#
#     Returns:
#         Number of degrees of freedom in block.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Now print the degrees of freedom for your model. The result should be 7.
# </div>

# %%
# Todo: print the degrees of freedom for your model

# %%
# Todo: print the degrees of freedom for your model
print("Degrees of Freedom =", degrees_of_freedom(m))
# Out:
# Degrees of Freedom = 7

# %%
# Check the degrees of freedom
assert degrees_of_freedom(m) == 7

# %% [markdown]
# ### 4.2 Specify Inlet Conditions
#
# To satisfy our degrees of freedom, we will first specify the inlet conditions. We can specify these values through the `inlet` port of the flash unit.
#
# **To see the list of naming conventions for variables within the IDAES framework, consult the online documentation at: https://idaes-pse.readthedocs.io/en/stable/explanations/conventions.html#standard-naming-format**
#
# As an  example, to fix the molar flow of the inlet to be 1.0, you can use the following notation:
# ```python
# m.fs.flash.inlet.flow_mol.fix(1.0)
# ```
#
# To specify variables that are indexed by components, you can use the following notation:
# ```python
# m.fs.flash.inlet.mole_frac_comp[0, "benzene"].fix(0.5)
# ```
#
# <div class="alert alert-block alert-warning">
# <b>Note:</b>
# The "0" in the indexing of the component mole fraction is present because IDAES models support both dynamic and steady state simulation, and the "0" refers to a time point. Dynamic modeling is beyond the scope of this workshop. Since we are performing steady state modeling, there is only a single time point in the model.
# </div>
#
# In the next cell, we will specify the inlet conditions. To satisfy the remaining degrees of freedom, we will make two additional specifications on the flash tank itself. The names of the key variables within the Flash unit model can also be found in the online documentation: https://idaes-pse.readthedocs.io/en/stable/reference_guides/model_libraries/generic/unit_models/flash.html#variables.
#
#
# To specify the value of a variable on the unit itself, use the following notation.
#
# ```python
# m.fs.flash.heat_duty.fix(0)
# ```
#
# For this module, we will use the following specifications:
# * inlet overall molar flow = 1.0 (`flow_mol`)
# * inlet temperature = 368 K (`temperature`)
# * inlet pressure = 101325 Pa (`pressure`)
# * inlet mole fraction (benzene) = 0.5 (`mole_frac_comp[0, "benzene"]`)
# * inlet mole fraction (toluene) = 0.5 (`mole_frac_comp[0, "toluene"]`)
# * The heat duty on the flash set to 0 (`heat_duty`)
# * The pressure drop across the flash tank set to 0 (`deltaP`)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Write the code below to specify the inlet conditions and unit specifications described above
# </div>

# %%
# Todo: Add inlet specifications given above


# Todo: Add 2 flash unit specifications given above

# %%
# Todo: Add inlet specifications given above
m.fs.flash.inlet.flow_mol.fix(1)
m.fs.flash.inlet.temperature.fix(368)
m.fs.flash.inlet.pressure.fix(101325)
m.fs.flash.inlet.mole_frac_comp[0, "benzene"].fix(0.5)
m.fs.flash.inlet.mole_frac_comp[0, "toluene"].fix(0.5)

# Todo: Add 2 flash unit specifications given above
m.fs.flash.heat_duty.fix(0)
m.fs.flash.deltaP.fix(0)

# %% [markdown]
# Now that all the inlets have been specified, we can check the degrees of freedom again to ensure the system is square and has a degree of freedom of 0.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Check the degrees of freedom again to ensure that the system is now square. You should see that the degrees of freedom is now 0.
# </div>

# %%
# Todo: print the degrees of freedom for your model

# %%
# Todo: print the degrees of freedom for your model
print("Degrees of Freedom =", degrees_of_freedom(m))
# Out:
# Degrees of Freedom = 0

# %%
# Check the degrees of freedom
assert degrees_of_freedom(m) == 0

# %% [markdown]
# ## 5 Initializing the Model
#
# Now that all building steps are complete, the last step before solving the model is to initialize the model, or prepping the solve by giving it a good starting point. This is essentially giving the solver an initial guess for the iterative solver to reach convergence and is essential for both a fast and accurate solution. In IDAES, the current standard for initializing the model is by utilizing initializer instances. These initializer instances contain the initialize method that can be applied to any model type. For more information on initializing in IDAES, visit https://idaes-pse.readthedocs.io/en/stable/reference_guides/initialization/index.html. <br>
#
# For this tutorial, we will import the initializer class `BlockTriangularizationInitializer` class from the `default_initializer` method from the flash unit model. This is often the simplest way to obtain a compatible initializer for each unit model, but you can also directly important any initializer needed from this source `idaes.core.initialization`. Each initializer instance contains the `initialize()` method that requires an argument to be initialized and in this case its the flash unit model.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Define the initializer instance, and initialize the flash unit model
# </div>

# %%
# Todo: initialize the flash unit

# %%
# Todo: initialize the flash unit
FlashInitializer = m.fs.flash.default_initializer()
FlashInitializer.initialize(m.fs.flash)
# Out:
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_in: Initialization Step 1 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_in: Initialization Step 2 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_in: Initialization Step 3 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_in: Initialization Step 4 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_in: Initialization Step 5 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_out: Initialization Step 1 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_out: Initialization Step 2 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_out: Initialization Step 3 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_out: Initialization Step 4 optimal - <undefined>.
# 2026-02-23 14:22:09 [INFO] idaes.init.fs.flash.control_volume.properties_out: Initialization Step 5 optimal - <undefined>.
# <InitializationStatus.Ok: 1>

# %% [markdown]
# Another option for initializing is utilizing the default initializer that is attached to the unit model. Each unit model as a default initializer that is hypothetically the most compatible. It can be called with `m.fs.flash.initialize()`. While this is an option, it is generally preferred to import an initializer object and initialize the model with that to ensure more control over the initialization.

# %% [markdown]
# ## 6 Solving the Model
#
# Now that the model has been defined and initialized, we can solve the model.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Using the notation described in the previous model, create an instance of the "ipopt" solver and use it to solve the model. Set the tee option to True to see the log output.
# </div>

# %%
# Todo: create the ipopt solver

# Todo: solve the model

# %%
# Todo: create the ipopt solver
solver = SolverFactory("ipopt")

# Todo: solve the model
status = solver.solve(m, tee=True)
# Out:
# WARNING: model contains export suffix 'scaling_factor' that contains 7
# component keys that are not exported as part of the NL file.  Skipping.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      135
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       72
#
# Total number of variables............................:       41
#                      variables with only lower bounds:        3
#                 variables with lower and upper bounds:       10
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       41
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.86e-10 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.4161313718316118e-12    3.8562575355172157e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.4161313718316118e-12    3.8562575355172157e-10
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
# Check for an optimal solution
from pyomo.environ import TerminationCondition

assert status.solver.termination_condition == TerminationCondition.optimal

# %% [markdown]
# ## 7 Viewing the Results
#
# Once a model is solved, the values returned by the solver are loaded into the model object itself. We can access the value of any variable in the model with the `value` function. For example:
# ```python
# print('Vap. Outlet Temperature = ', value(m.fs.flash.vap_outlet.temperature[0]))
# ```
#
# You can also find more information about a variable or an entire port using the `display` method from Pyomo:
# ```python
# m.fs.flash.vap_outlet.temperature.display()
# m.fs.flash.vap_outlet.display()
# ```
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the cells below to show the current value of the flash vapor outlet pressure. This cell also shows use of the display function to see the values of the variables in the vap_outlet and the liq_outlet.
# </div>

# %%
# Print the pressure of the flash vapor outlet
print("Pressure =", value(m.fs.flash.vap_outlet.pressure[0]))

print()
print("Output from display:")
# Call display on vap_outlet and liq_outlet of the flash
m.fs.flash.vap_outlet.display()
m.fs.flash.liq_outlet.display()
# Out:
# Pressure = 101325.0
#
# Output from display:
# vap_outlet : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 0.39611817487740925}
#          : mole_frac_comp : {(0.0, 'benzene'): 0.633976648508135, (0.0, 'toluene'): 0.366023351491865}
#          :       pressure : {0.0: 101325.0}
#          :    temperature : {0.0: 367.99999999999994}
# liq_outlet : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 0.6038818251225908}
#          : mole_frac_comp : {(0.0, 'benzene'): 0.412117597722934, (0.0, 'toluene'): 0.587882402277066}
#          :       pressure : {0.0: 101325.0}
#          :    temperature : {0.0: 367.99999999999994}

# %% [markdown]
# The output from `display` is quite exhaustive and not really intended to provide quick summary information. Because Pyomo is built on Python, there are opportunities to format the output any way we like. Most IDAES models have a `report` method which provides a summary of the results for the model.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the cell below which uses the function above to print a summary of the key variables in the flash model, including the inlet, the vapor, and the liquid ports.
# </div>

# %%
m.fs.flash.report()
# Out:
# ====================================================================================
# Unit : fs.flash                                                            Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value  : Units  : Fixed : Bounds
#           Heat Duty : 0.0000 :   watt :  True : (None, None)
#     Pressure Change : 0.0000 : pascal :  True : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                Units         Inlet    Vapor Outlet  Liquid Outlet
#     flow_mol                mole / second     1.0000      0.39612       0.60388
#     mole_frac_comp benzene  dimensionless    0.50000      0.63398       0.41212
#     mole_frac_comp toluene  dimensionless    0.50000      0.36602       0.58788
#     temperature                    kelvin     368.00       368.00        368.00
#     pressure                       pascal 1.0132e+05   1.0132e+05    1.0132e+05
# ====================================================================================

# %%
# Check optimal solution values
import pytest

assert value(m.fs.flash.liq_outlet.flow_mol[0]) == pytest.approx(0.6038, abs=1e-3)
assert value(m.fs.flash.liq_outlet.mole_frac_comp[0, "benzene"]) == pytest.approx(
    0.4121, abs=1e-3
)
assert value(m.fs.flash.liq_outlet.mole_frac_comp[0, "toluene"]) == pytest.approx(
    0.5878, abs=1e-3
)
assert value(m.fs.flash.liq_outlet.temperature[0]) == pytest.approx(368, abs=1e-3)
assert value(m.fs.flash.liq_outlet.pressure[0]) == pytest.approx(101325, abs=1e-3)

assert value(m.fs.flash.vap_outlet.flow_mol[0]) == pytest.approx(0.3961, abs=1e-3)
assert value(m.fs.flash.vap_outlet.mole_frac_comp[0, "benzene"]) == pytest.approx(
    0.6339, abs=1e-3
)
assert value(m.fs.flash.vap_outlet.mole_frac_comp[0, "toluene"]) == pytest.approx(
    0.3660, abs=1e-3
)
assert value(m.fs.flash.vap_outlet.temperature[0]) == pytest.approx(368, abs=1e-3)
assert value(m.fs.flash.vap_outlet.pressure[0]) == pytest.approx(101325, abs=1e-3)

# %% [markdown]
# ## Exercise: Studying Purity as a Function of Heat Duty
#
# Since the entire modeling framework is built upon Python, it includes a complete programming environment for whatever analysis we may want to perform. In this next exercise, we will make use of what we learned in this and the previous module to generate a figure showing some output variables as a function of the heat duty in the flash tank.
#
# First, let's import the matplotlib package for plotting as we did in the previous module.
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Execute the cell below to import matplotlib appropriately.
# </div>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Exercise specifications:
# * Generate a figure showing the flash tank heat duty (`m.fs.flash.heat_duty[0]`) vs. the vapor flowrate (`m.fs.flash.vap_outlet.flow_mol[0]`)
# * Specify the heat duty from -17000 to 25000 over 50 steps

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Using what you have learned so far, fill in the missing code below to generate the figure specified above. (Hint: import numpy and use the linspace function from the previous module)
# </div>

# %%
# import the solve_successful checking function from workshop tools
from idaes_examples.mod.tut.workshoptools import solve_successful

# Todo: import numpy as np


# create the empty lists to store the results that will be plotted
Q = []
V = []

# re-initialize model
UnitModelInitializer.initialize(m.fs.flash)

# Todo: Write the for loop specification using numpy's linspace

    # fix the heat duty
    m.fs.flash.heat_duty.fix(duty)

    # append the value of the duty to the Q list
    Q.append(duty)

    # print the current simulation
    print("Simulating with Q = ", value(m.fs.flash.heat_duty[0]))

    # Solve the model
    status = solver.solve(m)

    # append the value for vapor fraction if the solve was successful
    if solve_successful(status):
        V.append(value(m.fs.flash.vap_outlet.flow_mol[0]))
        print('... solve successful.')
    else:
        V.append(0.0)
        print('... solve failed.')

# Create and show the figure
plt.figure("Vapor Fraction")
plt.plot(Q, V)
plt.grid()
plt.xlabel("Heat Duty [J]")
plt.ylabel("Vapor Fraction [-]")
plt.show()
# Out:
#   Cell In[34], line 17
#     m.fs.flash.heat_duty.fix(duty)
#     ^
# IndentationError: unexpected indent

# %%
# import the solve_successful checking function from workshop tools
from idaes_examples.mod.tut.workshoptools import solve_successful

# Todo: import numpy
import numpy as np

# create the empty lists to store the results that will be plotted
Q = []
V = []

# re-initialize model
FlashInitializer.initialize(m.fs.flash)

# Todo: Write the for loop specification using numpy's linspace
for duty in np.linspace(-17000, 25000, 50):
    # fix the heat duty
    m.fs.flash.heat_duty.fix(duty)

    # append the value of the duty to the Q list
    Q.append(duty)

    # print the current simulation
    print("Simulating with Q = ", value(m.fs.flash.heat_duty[0]))

    # Solve the model
    status = solver.solve(m)

    # append the value for vapor fraction if the solve was successful
    if solve_successful(status):
        V.append(value(m.fs.flash.vap_outlet.flow_mol[0]))
        print("... solve successful.")
    else:
        V.append(0.0)
        print("... solve failed.")

# Create and show the figure
plt.figure("Vapor Fraction")
plt.plot(Q, V)
plt.grid()
plt.xlabel("Heat Duty [J]")
plt.ylabel("Vapor Fraction [-]")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Repeat the exercise above, but create a figure showing the heat duty vs. the mole fraction of Benzene in the vapor outlet. Remove any unnecessary printing to create cleaner results.
# </div>

# %%
# Todo: generate a figure of heat duty vs. mole fraction of Benzene in the vapor

# %%
# Todo: generate a figure of heat duty vs. mole fraction of Benzene in the vapor
Q = []
V = []

for duty in np.linspace(-17000, 25000, 50):
    # fix the heat duty
    m.fs.flash.heat_duty.fix(duty)

    # append the value of the duty to the Q list
    Q.append(duty)

    # print the current simulation
    print("Simulating with Q = ", value(m.fs.flash.heat_duty[0]))

    # solve the model
    status = solver.solve(m)

    # append the value for vapor fraction if the solve was successful
    if solve_successful(status):
        V.append(value(m.fs.flash.vap_outlet.mole_frac_comp[0, "benzene"]))
        print("... solve successful.")
    else:
        V.append(0.0)
        print("... solve failed.")

plt.figure("Purity")
plt.plot(Q, V)
plt.grid()
plt.xlabel("Heat Duty [J]")
plt.ylabel("Vapor Benzene Mole Fraction [-]")
plt.show()

# %% [markdown]
# Recall that the IDAES framework is an equation-oriented modeling environment. This means that we can specify "design" problems natively. That is, there is no need to have our specifications on the inlet alone. We can put specifications on the outlet as long as we retain a well-posed, square system of equations.
#
# For example, we can remove the specification on heat duty and instead specify that we want the mole fraction of Benzene in the vapor outlet to be equal to 0.6. The mole fraction is not a native variable in the property block, so we cannot use "fix". We can, however, add a constraint to the model.
#
# Note that we have been executing a number of solves on the problem, and may not be sure of the current state. To help convergence, therefore, we will first call initialize, then add the new constraint and solve the problem. Note that the reference for the mole fraction of Benzene in the vapor outlet is `m.fs.flash.vap_outlet.mole_frac_comp[0, "benzene"]`.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Fill in the missing code below and add a constraint on the mole fraction of Benzene (to a value of 0.6) to find the required heat duty.
# </div>

# %%
# re-initialize the model - this may or may not be required depending on current state but safe to initialize
m.fs.flash.heat_duty.fix(0)
m.fs.flash.initialize(outlvl=idaeslog.WARNING)

# Unfix the heat_duty variable
m.fs.flash.heat_duty.unfix()

# Todo: Add a new constraint (benzene mole fraction to 0.6)

# solve the problem
status = solver.solve(m, tee=True)

# Check stream condition
m.fs.flash.report()

# %%
# re-initialize the model - this may or may not be required depending on current state but safe to initialize
m.fs.flash.heat_duty.fix(0)
m.fs.flash.initialize(outlvl=idaeslog.WARNING)

# Unfix the heat_duty variable
m.fs.flash.heat_duty.unfix()

# Todo: Add a new constraint (benzene mole fraction to 0.6)
m.benz_purity_con = Constraint(
    expr=m.fs.flash.vap_outlet.mole_frac_comp[0, "benzene"] == 0.6
)

# solve the problem
status = solver.solve(m, tee=True)

# Check stream condition
m.fs.flash.report()

# %%
# Check for solver status
assert status.solver.termination_condition == TerminationCondition.optimal

# Check for optimal values
assert value(m.fs.flash.liq_outlet.flow_mol[0]) == pytest.approx(0.4516, abs=1e-3)
assert value(m.fs.flash.liq_outlet.mole_frac_comp[0, "benzene"]) == pytest.approx(
    0.3786, abs=1e-3
)
assert value(m.fs.flash.liq_outlet.mole_frac_comp[0, "toluene"]) == pytest.approx(
    0.6214, abs=1e-3
)
assert value(m.fs.flash.liq_outlet.temperature[0]) == pytest.approx(369.07, abs=1e-2)
assert value(m.fs.flash.liq_outlet.pressure[0]) == pytest.approx(101325, abs=1e-3)

assert value(m.fs.flash.vap_outlet.flow_mol[0]) == pytest.approx(0.5483, abs=1e-3)
assert value(m.fs.flash.vap_outlet.mole_frac_comp[0, "benzene"]) == pytest.approx(
    0.6, abs=1e-3
)
assert value(m.fs.flash.vap_outlet.mole_frac_comp[0, "toluene"]) == pytest.approx(
    0.4, abs=1e-3
)
assert value(m.fs.flash.vap_outlet.temperature[0]) == pytest.approx(369.07, abs=1e-2)
assert value(m.fs.flash.vap_outlet.pressure[0]) == pytest.approx(101325, abs=1e-3)
